# %%
import matplotlib.pyplot as plt
from tabulate import tabulate               
import matplotlib as mat                    
import seaborn as sns                       
import pandas as pd                        
import numpy as np

# %%
df = pd.read_csv("DS1_C6_S2_EmployeeAttrition_Data_Concept.csv")
df
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 0     41.0       Yes      Travel_Rarely                   Sales
# 1     49.0        No  Travel_Frequently  Research & Development
# 2     37.0       Yes      Travel_Rarely  Research & Development
# 3     33.0        No  Travel_Frequently  Research & Development
# 4     27.0        No      Travel_Rarely  Research & Development
# ...    ...       ...                ...                     ...
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 0                    1  Life Sciences               1
# 1                    8  Life Sciences               2
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") 
    print(f"Mode of {col} is {df[col].mode()[0]}")  
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}")

# %%
##  Q 1. Analysis of Attrition Flag: If the employee is Attired or Not.

# %%
info_of_cat("Attrition")
# Out:
# Unique values in Attrition are: ['Yes' 'No']
# Mode of Attrition is No
# Number of missing values in Attrition is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of Attrition")                 
percentage = df["Attrition"].value_counts()         
labels = list(df["Attrition"].value_counts().index) 

sns.countplot(x = df["Attrition"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")
plt.show()

# %% [markdown]
# # ***Interpretation:  The dataset indicates that 16% of the employee left from the company while 83% of the employee are still working.

# %%
## 2. Analysis of  Gender column: Gender of a person (Male or Female)

# %%
info_of_cat("Gender")
# Out:
# Unique values in Gender are: ['Female' 'Male' nan]
# Mode of Gender is Male
# Number of missing values in Gender is 45

# %%
gender_mode = df.Gender.mode()[0]
print(gender_mode)
df["Gender"].fillna(gender_mode, inplace = True)
# Out:
# Male

# %%
info_of_cat("Gender")
# Out:
# Unique values in Gender are: ['Female' 'Male']
# Mode of Gender is Male
# Number of missing values in Gender is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
data = df["Gender"].value_counts()                                                           
labels =data.keys()                                                   
                                                                     
sns.countplot(x = df["Gender"], ax = ax[0])
plt.pie(x = data, autopct = "%.1f%%", explode = [0.02, 0.0], labels = labels, pctdistance = 0.5) 
                                                                     
                                                                    
                                                                     
plt.show()

# %% [markdown]
# # ***Interpretation: Male employee are working more in number and they are contributing to 60% compare to female employee.

# %%
## 3. Analysis of  BusinessTravel column: whether they are travelling for business purpose?

# %%
info_of_cat("BusinessTravel")
# Out:
# Unique values in BusinessTravel are: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel' nan]
# Mode of BusinessTravel is Travel_Rarely
# Number of missing values in BusinessTravel is 30

# %%
Business_travel = df.BusinessTravel.mode()[0]
print(Business_travel)
df["BusinessTravel"].fillna(Business_travel, inplace = True)
# Out:
# Travel_Rarely

# %%
info_of_cat("BusinessTravel")
# Out:
# Unique values in BusinessTravel are: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Mode of BusinessTravel is Travel_Rarely
# Number of missing values in BusinessTravel is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["BusinessTravel"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["BusinessTravel"], ax = ax[0])
labels = list(df["BusinessTravel"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# Travel_Rarely        71.700680
# Travel_Frequently    18.231293
# Non-Travel           10.068027
# Name: BusinessTravel, dtype: float64

# %% [markdown]
# # ***Interpretation: 71% employee are travel rarely for business purpose, and 18% of employee travel ferquenlty whereas only 10% of employee are not travelling.

# %%
## 4. Analysis of department column.

# %%
info_of_cat("Department")
# Out:
# Unique values in Department are: ['Sales' 'Research & Development' 'Human Resources' nan]
# Mode of Department is Research & Development
# Number of missing values in Department is 4

# %%
department_mode = df.Department.mode()[0]
print(department_mode)
df["Department"].fillna(department_mode, inplace = True)
# Out:
# Research & Development

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["Department"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["Department"], ax = ax[0])
labels = list(df["Department"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# Research & Development    65.374150
# Sales                     30.340136
# Human Resources            4.285714
# Name: Department, dtype: float64

# %% [markdown]
# ***Interpretation: 65% of employee are belonging from Research Department and are having most number of employee
#
# and, 30% of employee are from Sales department and less number of employee i.e only 4% from Sales department.

# %%
info_of_cat("EducationField")
# Out:
# Unique values in EducationField are: ['Life Sciences' 'Other' 'Medical' 'Marketing' nan 'Technical Degree'
#  'Human Resources']
# Mode of EducationField is Life Sciences
# Number of missing values in EducationField is 12

# %%
EducationField_mode = df.EducationField.mode()[0]
print(EducationField_mode)
df["EducationField"].fillna(EducationField_mode, inplace = True)
# Out:
# Life Sciences

# %%
info_of_cat("EducationField")
# Out:
# Unique values in EducationField are: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Mode of EducationField is Life Sciences
# Number of missing values in EducationField is 0

# %%
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["EducationField"])
for bar in ax.patches:                                              # ax.patches returns the rectange object from matplotlib
    percentage = f"{round(bar.get_height() /len(df), 2)}%"          # first it calculate the bar height and then dividing by the number of rows in data(to calculate percentage) 
                                                                    # and multiply with 100 to get the percentage and rounding of by 2 numbers.  
    x = bar.get_x() + bar.get_width() /2                            # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
    y = bar.get_height()                                            # get_height: returns height of rectange
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )   # va bottom: means percentage would be above the bar head. 
                                                                    # annotate: used to annotate over objects, here objects are the bars
plt.show()

# %% [markdown]
# ## ***Interpretation: Employee are usually from Life science and medical field which adds up to 73% of the total employee

# %%
info_of_cat("EnvironmentSatisfaction")
# Out:
# Unique values in EnvironmentSatisfaction are: [2 3 4 1]
# Mode of EnvironmentSatisfaction is 3
# Number of missing values in EnvironmentSatisfaction is 0

# %%
def bar_percentage(ax, count: "number of rows in data "):
    for bar in ax.patches:                                            # ax.patches returns the rectange object from matplotlib
        percentage = f"{round((bar.get_height() / count) *100, 2)}%"  # first it calculate the bar height and then dividing by the number of row(to calculate percentage)
                                                                            # in data and multiply with 100 to get the percentage and rounding of by 2 numbers.
        x = bar.get_x() + bar.get_width() /2                          # get_x: returns the left corrdinate of the rectange, get_width: returns width of rectagle
        y = bar.get_height()                                          # get_height: returns height of rectangle bar.
        ax.annotate(percentage, (x, y), va = "bottom", ha = "center") # va: Vertical axis: -> top means percentage would bneath the bar head. top, bottom or center 
                                                                      # ha: Horizontal axis:-> how you want to keep it. can be changed to center, left, right.
                                                                      # annotate: used to annotate over objects. here objects are the bars 
    plt.show()

# %%
fig, ax = plt.subplots(figsize  = (10 , 6))
ax = sns.countplot(x = df["EnvironmentSatisfaction"])
bar_percentage(ax, len(df))

# %%
info_of_cat("JobInvolvement")
# Out:
# Unique values in JobInvolvement are: [3 2 4 1]
# Mode of JobInvolvement is 3
# Number of missing values in JobInvolvement is 0

# %%
fig, ax = plt.subplots(figsize  = (10 , 6))
ax = sns.countplot(x = df["JobInvolvement"])
bar_percentage(ax, len(df))

# %%
info_of_cat("JobSatisfaction")
# Out:
# Unique values in JobSatisfaction are: [4 2 3 1]
# Mode of JobSatisfaction is 4
# Number of missing values in JobSatisfaction is 0

# %%
fig, ax = plt.subplots(figsize  = (10 , 6))
ax = sns.countplot(x = df["JobSatisfaction"])
bar_percentage(ax, len(df))

# %%
df.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       Yes      Travel_Rarely                   Sales
# 1  49.0        No  Travel_Frequently  Research & Development
# 2  37.0       Yes      Travel_Rarely  Research & Development
# 3  33.0        No  Travel_Frequently  Research & Development
# 4  27.0        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0                 1  Life Sciences               1                        2
# 1                 8  Life Sciences               2                        3
# 2                 2          Other               4                        4
# 3                 3  Life Sciences               5                        4
# 4                 2        Medical               7                        1
#
#    Gender  HourlyRate  ...  OverTime PerformanceRating  \
# 0  Female          94  ...       Yes                 3
# ...

# %%
info_of_cat("DistanceFromHome")
# Out:
# Unique values in DistanceFromHome are: [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# Mode of DistanceFromHome is 2
# Number of missing values in DistanceFromHome is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["DistanceFromHome"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["DistanceFromHome"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %%
info_of_numerical("HourlyRate")
# Out:
# The mean of the HourlyRate is 65.89115646258503
# The median of the HourlyRate is 66.0
# The mode of the HourlyRate is 66
# The standard deviation of the HourlyRate is 20.329427593996158
# Number of missing values in the HourlyRate is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["HourlyRate"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["HourlyRate"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
info_of_cat("JobRole")
# Out:
# Unique values in JobRole are: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' nan 'Human Resources']
# Mode of JobRole is Sales Executive
# Number of missing values in JobRole is 10

# %%
JobRole_mode = df.JobRole.mode()[0]
print(JobRole_mode)
df["JobRole"].fillna(JobRole_mode, inplace = True)
# Out:
# Sales Executive

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["JobRole"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["JobRole"], ax = ax[0])
labels = list(df["JobRole"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# Sales Executive              22.653061
# Research Scientist           19.659864
# Laboratory Technician        17.619048
# Manufacturing Director        9.795918
# Healthcare Representative     8.843537
# Manager                       6.870748
# Sales Representative          5.646259
# Research Director             5.374150
# Human Resources               3.537415
# Name: JobRole, dtype: float64

# %%
info_of_cat("MaritalStatus")
# Out:
# Unique values in MaritalStatus are: ['Single' 'Married' nan 'Divorced']
# Mode of MaritalStatus is Married
# Number of missing values in MaritalStatus is 56

# %%
MaritalStatus_mode = df.MaritalStatus.mode()[0]
print(MaritalStatus_mode)
df["MaritalStatus"].fillna(MaritalStatus_mode, inplace = True)
# Out:
# Married

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["MaritalStatus"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["MaritalStatus"], ax = ax[0])
labels = list(df["MaritalStatus"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# Married     48.027211
# Single      30.544218
# Divorced    21.428571
# Name: MaritalStatus, dtype: float64

# %%
info_of_numerical("MonthlyIncome")
# Out:
# The mean of the MonthlyIncome is 6502.931292517007
# The median of the MonthlyIncome is 4919.0
# The mode of the MonthlyIncome is 2342
# The standard deviation of the MonthlyIncome is 4707.956783097995
# Number of missing values in the MonthlyIncome is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["MonthlyIncome"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["MonthlyIncome"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
info_of_cat("NumCompaniesWorked")
# Out:
# Unique values in NumCompaniesWorked are: [8 1 6 9 0 4 5 2 7 3]
# Mode of NumCompaniesWorked is 1
# Number of missing values in NumCompaniesWorked is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["NumCompaniesWorked"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["NumCompaniesWorked"], ax = ax[0])
labels = list(df["NumCompaniesWorked"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# 1    35.442177
# 0    13.401361
# 3    10.816327
# 2     9.931973
# 4     9.455782
# 7     5.034014
# 6     4.761905
# 5     4.285714
# 9     3.537415
# 8     3.333333
# Name: NumCompaniesWorked, dtype: float64

# %%
info_of_cat("Over18")
# Out:
# Unique values in Over18 are: ['Y' nan]
# Mode of Over18 is Y
# Number of missing values in Over18 is 54

# %%
Over18_mode = df.Over18.mode()[0]
print(Over18_mode)
df["Over18"].fillna(Over18_mode, inplace = True)
# Out:
# Y

# %%
info_of_cat("OverTime")
# Out:
# Unique values in OverTime are: ['Yes' 'No']
# Mode of OverTime is No
# Number of missing values in OverTime is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["OverTime"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["OverTime"], ax = ax[0])
labels = list(df["OverTime"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# No     71.70068
# Yes    28.29932
# Name: OverTime, dtype: float64

# %%
info_of_cat("PerformanceRating")
# Out:
# Unique values in PerformanceRating are: [3 4]
# Mode of PerformanceRating is 3
# Number of missing values in PerformanceRating is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["PerformanceRating"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["PerformanceRating"], ax = ax[0])
labels = list(df["PerformanceRating"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# 3    84.62585
# 4    15.37415
# Name: PerformanceRating, dtype: float64

# %%
info_of_cat("RelationshipSatisfaction")
# Out:
# Unique values in RelationshipSatisfaction are: [1 4 2 3]
# Mode of RelationshipSatisfaction is 3
# Number of missing values in RelationshipSatisfaction is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["RelationshipSatisfaction"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["RelationshipSatisfaction"], ax = ax[0])
labels = list(df["RelationshipSatisfaction"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# 3    31.224490
# 4    29.387755
# 2    20.612245
# 1    18.775510
# Name: RelationshipSatisfaction, dtype: float64

# %%
info_of_numerical("TotalWorkingYears")
# Out:
# The mean of the TotalWorkingYears is 11.279591836734694
# The median of the TotalWorkingYears is 10.0
# The mode of the TotalWorkingYears is 10
# The standard deviation of the TotalWorkingYears is 7.780781675515004
# Number of missing values in the TotalWorkingYears is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["TotalWorkingYears"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["TotalWorkingYears"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
info_of_numerical("TrainingTimesLastYear")
# Out:
# The mean of the TrainingTimesLastYear is 2.7993197278911564
# The median of the TrainingTimesLastYear is 3.0
# The mode of the TrainingTimesLastYear is 2
# The standard deviation of the TrainingTimesLastYear is 1.2892706207958435
# Number of missing values in the TrainingTimesLastYear is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["TrainingTimesLastYear"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["TrainingTimesLastYear"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
info_of_cat("WorkLifeBalance")
# Out:
# Unique values in WorkLifeBalance are: [1 3 2 4]
# Mode of WorkLifeBalance is 3
# Number of missing values in WorkLifeBalance is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 6))
percentage = (df["WorkLifeBalance"].value_counts()/len(df))*100      
                                                                        
print(percentage)
sns.countplot(x = df["WorkLifeBalance"], ax = ax[0])
labels = list(df["WorkLifeBalance"].value_counts().index)           
                                                                         
ax[1].pie(percentage,labels = labels, autopct= "%0.2f%%")           
plt.show()
# Out:
# 3    60.748299
# 2    23.401361
# 4    10.408163
# 1     5.442177
# Name: WorkLifeBalance, dtype: float64

# %%
info_of_numerical("YearsAtCompany")
# Out:
# The mean of the YearsAtCompany is 7.0081632653061225
# The median of the YearsAtCompany is 5.0
# The mode of the YearsAtCompany is 5
# The standard deviation of the YearsAtCompany is 6.126525152403566
# Number of missing values in the YearsAtCompany is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["YearsAtCompany"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["YearsAtCompany"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
info_of_numerical("YearsInCurrentRole")
# Out:
# The mean of the YearsInCurrentRole is 4.229251700680272
# The median of the YearsInCurrentRole is 3.0
# The mode of the YearsInCurrentRole is 2
# The standard deviation of the YearsInCurrentRole is 3.6231370346706395
# Number of missing values in the YearsInCurrentRole is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["YearsInCurrentRole"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["YearsInCurrentRole"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
info_of_numerical("YearsSinceLastPromotion")
# Out:
# The mean of the YearsSinceLastPromotion is 2.1877551020408164
# The median of the YearsSinceLastPromotion is 1.0
# The mode of the YearsSinceLastPromotion is 0
# The standard deviation of the YearsSinceLastPromotion is 3.222430279137968
# Number of missing values in the YearsSinceLastPromotion is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["YearsSinceLastPromotion"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["YearsSinceLastPromotion"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
info_of_numerical("YearsWithCurrManager")
# Out:
# The mean of the YearsWithCurrManager is 4.12312925170068
# The median of the YearsWithCurrManager is 3.0
# The mode of the YearsWithCurrManager is 2
# The standard deviation of the YearsWithCurrManager is 3.5681361205404407
# Number of missing values in the YearsWithCurrManager is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["YearsWithCurrManager"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["YearsWithCurrManager"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()
